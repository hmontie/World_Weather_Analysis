# %% [markdown]
# ### Challenge PART 1 Get the weather descriptiopn and amount of precipitation for each city

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitudes  and longitudes combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities =[]

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city the unique then add it to cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 617

# %%
# Import the request library
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=903e6bcf80e6cf65b40ffb772ed1c1c6

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
            
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | toul
# Processing Record 3 of Set 1 | nalut
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | jacmel
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | marakkanam
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | panaci
# Processing Record 13 of Set 1 | valdivia
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | nadym
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | kamaishi
# Processing Record 18 of Set 1 | lavumisa
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | sakakah
# Processing Record 21 of Set 1 | mantua
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | ughelli
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | maunabo
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | port-gentil
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | almeirim
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | taywarah
# Processing Record 35 of Set 1 | caico
# Processing Record 36 of Set 1 | gornopravdinsk
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | tomatlan
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | mugumu
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | carutapera
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | lasa
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | los alamos
# Processing Record 50 of Set 1 | cockburn town
# Processing Record 1 of Set 2 | kahului
# Processing Record 2 of Set 2 | taoudenni
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | puri
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | ayan
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | merritt island
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | kongolo
# Processing Record 13 of Set 2 | hobyo
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | atasu
# Processing Record 17 of Set 2 | tautira
# Processing Record 18 of Set 2 | santa cruz
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | marsa matruh
# Processing Record 27 of Set 2 | pemba
# Processing Record 28 of Set 2 | la asuncion
# Processing Record 29 of Set 2 | vestmannaeyjar
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | pimenteiras
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | innisfail
# Processing Record 35 of Set 2 | papantla
# City not found. Skipping...
# Processing Record 36 of Set 2 | qom
# Processing Record 37 of Set 2 | yushu
# Processing Record 38 of Set 2 | illapel
# Processing Record 39 of Set 2 | maarianhamina
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | celestun
# Processing Record 42 of Set 2 | bathsheba
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | mana
# Processing Record 45 of Set 2 | tiznit
# Processing Record 46 of Set 2 | filadelfia
# Processing Record 47 of Set 2 | pastos bons
# Processing Record 48 of Set 2 | komsomolskiy
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | sorland
# Processing Record 1 of Set 3 | selcuk
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | auki
# Processing Record 4 of Set 3 | brigham city
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | deputatskiy
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | oga
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | pangnirtung
# Processing Record 11 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | palmer
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | huilong
# Processing Record 18 of Set 3 | half moon bay
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | chara
# Processing Record 21 of Set 3 | hami
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | yarensk
# Processing Record 24 of Set 3 | mount gambier
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | san juan
# Processing Record 27 of Set 3 | sioux lookout
# Processing Record 28 of Set 3 | marica
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | ahipara
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | clinton
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | nemuro
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | damietta
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | roma
# Processing Record 40 of Set 3 | togur
# Processing Record 41 of Set 3 | inyonga
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | maraa
# Processing Record 44 of Set 3 | waipawa
# Processing Record 45 of Set 3 | nongan
# Processing Record 46 of Set 3 | matara
# Processing Record 47 of Set 3 | bubaque
# Processing Record 48 of Set 3 | ojinaga
# Processing Record 49 of Set 3 | sao joao da barra
# Processing Record 50 of Set 3 | clyde river
# Processing Record 1 of Set 4 | pokrovka
# Processing Record 2 of Set 4 | muravlenko
# Processing Record 3 of Set 4 | batemans bay
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | kushiro
# Processing Record 6 of Set 4 | yerbogachen
# Processing Record 7 of Set 4 | san quintin
# Processing Record 8 of Set 4 | turayf
# Processing Record 9 of Set 4 | kudahuvadhoo
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | chase
# Processing Record 13 of Set 4 | lorengau
# Processing Record 14 of Set 4 | kokopo
# Processing Record 15 of Set 4 | haines junction
# Processing Record 16 of Set 4 | boende
# Processing Record 17 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 18 of Set 4 | yichang
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | roros
# Processing Record 21 of Set 4 | vanimo
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | belaya gora
# Processing Record 24 of Set 4 | todos santos
# Processing Record 25 of Set 4 | kangaba
# Processing Record 26 of Set 4 | bonavista
# Processing Record 27 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 4 | shahrud
# Processing Record 29 of Set 4 | clemmons
# Processing Record 30 of Set 4 | isangel
# Processing Record 31 of Set 4 | hofn
# Processing Record 32 of Set 4 | jaipur
# Processing Record 33 of Set 4 | ponta delgada
# Processing Record 34 of Set 4 | burns lake
# Processing Record 35 of Set 4 | faanui
# Processing Record 36 of Set 4 | acajutla
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | karratha
# Processing Record 39 of Set 4 | chalmette
# Processing Record 40 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 4 | eureka
# Processing Record 42 of Set 4 | effingham
# Processing Record 43 of Set 4 | santa rosalia
# Processing Record 44 of Set 4 | luena
# Processing Record 45 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 46 of Set 4 | chiman
# Processing Record 47 of Set 4 | dharchula
# Processing Record 48 of Set 4 | pizhma
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 5 | yumen
# Processing Record 5 of Set 5 | riyadh
# Processing Record 6 of Set 5 | tomball
# Processing Record 7 of Set 5 | yoro
# Processing Record 8 of Set 5 | ayr
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | sola
# Processing Record 11 of Set 5 | broome
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | xiongyue
# Processing Record 14 of Set 5 | aklavik
# Processing Record 15 of Set 5 | ulaanbaatar
# Processing Record 16 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 5 | savelugu
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | tromso
# Processing Record 20 of Set 5 | nichinan
# Processing Record 21 of Set 5 | valparaiso
# Processing Record 22 of Set 5 | asahikawa
# Processing Record 23 of Set 5 | adrar
# Processing Record 24 of Set 5 | joshimath
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | obera
# Processing Record 27 of Set 5 | umkomaas
# Processing Record 28 of Set 5 | mbandaka
# Processing Record 29 of Set 5 | gogrial
# Processing Record 30 of Set 5 | dickinson
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | peruibe
# Processing Record 33 of Set 5 | nsanje
# Processing Record 34 of Set 5 | kholodnyy
# Processing Record 35 of Set 5 | seoul
# Processing Record 36 of Set 5 | zhigansk
# Processing Record 37 of Set 5 | zyryanovsk
# Processing Record 38 of Set 5 | cap malheureux
# Processing Record 39 of Set 5 | ballina
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | sudbury
# Processing Record 43 of Set 5 | ekhabi
# Processing Record 44 of Set 5 | san cristobal
# Processing Record 45 of Set 5 | chuy
# Processing Record 46 of Set 5 | baglan
# Processing Record 47 of Set 5 | derzhavinsk
# Processing Record 48 of Set 5 | bac lieu
# Processing Record 49 of Set 5 | lashio
# Processing Record 50 of Set 5 | khandyga
# Processing Record 1 of Set 6 | segovia
# Processing Record 2 of Set 6 | alta floresta
# Processing Record 3 of Set 6 | cayenne
# Processing Record 4 of Set 6 | nouadhibou
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | dikson
# Processing Record 7 of Set 6 | almaznyy
# Processing Record 8 of Set 6 | berdigestyakh
# Processing Record 9 of Set 6 | silver city
# Processing Record 10 of Set 6 | rockport
# Processing Record 11 of Set 6 | nabire
# Processing Record 12 of Set 6 | norman wells
# Processing Record 13 of Set 6 | samarai
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | altay
# Processing Record 16 of Set 6 | faratsiho
# Processing Record 17 of Set 6 | atikokan
# Processing Record 18 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 6 | malakal
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | corrente
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | chany
# Processing Record 24 of Set 6 | jambi
# Processing Record 25 of Set 6 | fort nelson
# Processing Record 26 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 6 | kenai
# Processing Record 28 of Set 6 | mecca
# Processing Record 29 of Set 6 | flinders
# Processing Record 30 of Set 6 | port alfred
# Processing Record 31 of Set 6 | honiara
# Processing Record 32 of Set 6 | pimentel
# Processing Record 33 of Set 6 | ferkessedougou
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | jam sahib
# Processing Record 36 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 6 | aripuana
# Processing Record 38 of Set 6 | burnie
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | samfya
# Processing Record 41 of Set 6 | sawakin
# Processing Record 42 of Set 6 | poum
# Processing Record 43 of Set 6 | renukut
# Processing Record 44 of Set 6 | montes claros
# Processing Record 45 of Set 6 | san jeronimo
# Processing Record 46 of Set 6 | los llanos de aridane
# Processing Record 47 of Set 6 | praia da vitoria
# Processing Record 48 of Set 6 | puerto escondido
# Processing Record 49 of Set 6 | calvinia
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | caranavi
# Processing Record 2 of Set 7 | nanning
# Processing Record 3 of Set 7 | la ronge
# Processing Record 4 of Set 7 | avarua
# Processing Record 5 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 6 of Set 7 | jijiga
# Processing Record 7 of Set 7 | whitianga
# Processing Record 8 of Set 7 | sao geraldo do araguaia
# Processing Record 9 of Set 7 | miri
# Processing Record 10 of Set 7 | sharjah
# Processing Record 11 of Set 7 | ushtobe
# Processing Record 12 of Set 7 | atambua
# Processing Record 13 of Set 7 | penticton
# Processing Record 14 of Set 7 | college
# Processing Record 15 of Set 7 | esperance
# Processing Record 16 of Set 7 | ostrovnoy
# Processing Record 17 of Set 7 | taltal
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | kazanskaya
# Processing Record 20 of Set 7 | ketchikan
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | ulverstone
# Processing Record 23 of Set 7 | asfi
# Processing Record 24 of Set 7 | springbok
# Processing Record 25 of Set 7 | dindori
# Processing Record 26 of Set 7 | pitimbu
# Processing Record 27 of Set 7 | salta
# Processing Record 28 of Set 7 | izberbash
# Processing Record 29 of Set 7 | kruisfontein
# Processing Record 30 of Set 7 | tezu
# Processing Record 31 of Set 7 | saskylakh
# Processing Record 32 of Set 7 | gazimurskiy zavod
# Processing Record 33 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 7 | faya
# Processing Record 36 of Set 7 | husavik
# Processing Record 37 of Set 7 | curup
# Processing Record 38 of Set 7 | paamiut
# Processing Record 39 of Set 7 | padang
# Processing Record 40 of Set 7 | siniscola
# Processing Record 41 of Set 7 | cabo san lucas
# Processing Record 42 of Set 7 | nuuk
# Processing Record 43 of Set 7 | dolores
# Processing Record 44 of Set 7 | chulym
# Processing Record 45 of Set 7 | ushiku
# Processing Record 46 of Set 7 | ancud
# Processing Record 47 of Set 7 | meiganga
# Processing Record 48 of Set 7 | terrace
# Processing Record 49 of Set 7 | sakskobing
# Processing Record 50 of Set 7 | viedma
# Processing Record 1 of Set 8 | dingle
# Processing Record 2 of Set 8 | oktyabrskoye
# Processing Record 3 of Set 8 | smithers
# Processing Record 4 of Set 8 | guiratinga
# Processing Record 5 of Set 8 | maragogi
# Processing Record 6 of Set 8 | gushikawa
# Processing Record 7 of Set 8 | pativilca
# Processing Record 8 of Set 8 | ordzhonikidze
# Processing Record 9 of Set 8 | balabac
# Processing Record 10 of Set 8 | boca do acre
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | benemerito de las americas
# Processing Record 13 of Set 8 | livingston
# Processing Record 14 of Set 8 | sur
# Processing Record 15 of Set 8 | den helder
# Processing Record 16 of Set 8 | verkhnetulomskiy
# Processing Record 17 of Set 8 | saint george
# Processing Record 18 of Set 8 | saravan
# Processing Record 19 of Set 8 | baghmara
# Processing Record 20 of Set 8 | raha
# Processing Record 21 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 8 | rawah
# Processing Record 24 of Set 8 | lebyazhye
# Processing Record 25 of Set 8 | channel-port aux basques
# Processing Record 26 of Set 8 | klyuchi
# Processing Record 27 of Set 8 | rawson
# Processing Record 28 of Set 8 | kirakira
# Processing Record 29 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 31 of Set 8 | mirabad
# Processing Record 32 of Set 8 | port lincoln
# Processing Record 33 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 34 of Set 8 | comodoro rivadavia
# Processing Record 35 of Set 8 | oranjestad
# Processing Record 36 of Set 8 | honningsvag
# Processing Record 37 of Set 8 | hay river
# Processing Record 38 of Set 8 | timmins
# Processing Record 39 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 8 | opole lubelskie
# Processing Record 41 of Set 8 | rudbar
# Processing Record 42 of Set 8 | cidreira
# Processing Record 43 of Set 8 | bereda
# Processing Record 44 of Set 8 | narrabri
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | sydney
# Processing Record 47 of Set 8 | nome
# Processing Record 48 of Set 8 | kutum
# Processing Record 49 of Set 8 | sergeyevka
# Processing Record 50 of Set 8 | kamyaran
# Processing Record 1 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | mayumba
# Processing Record 4 of Set 9 | north bend
# Processing Record 5 of Set 9 | nelson bay
# Processing Record 6 of Set 9 | japura
# Processing Record 7 of Set 9 | palanpur
# Processing Record 8 of Set 9 | dunedin
# Processing Record 9 of Set 9 | margate
# Processing Record 10 of Set 9 | tasiilaq
# Processing Record 11 of Set 9 | trairi
# Processing Record 12 of Set 9 | brae
# Processing Record 13 of Set 9 | san policarpo
# Processing Record 14 of Set 9 | maracacume
# Processing Record 15 of Set 9 | grand-santi
# Processing Record 16 of Set 9 | bambanglipuro
# Processing Record 17 of Set 9 | port augusta
# Processing Record 18 of Set 9 | kodinsk
# Processing Record 19 of Set 9 | boden
# Processing Record 20 of Set 9 | vagur
# Processing Record 21 of Set 9 | arlit
# Processing Record 22 of Set 9 | puro
# Processing Record 23 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 9 | dabra
# Processing Record 25 of Set 9 | byron bay
# Processing Record 26 of Set 9 | provideniya
# Processing Record 27 of Set 9 | talnakh
# Processing Record 28 of Set 9 | pocone
# Processing Record 29 of Set 9 | sakaiminato
# Processing Record 30 of Set 9 | achisu
# Processing Record 31 of Set 9 | quchan
# Processing Record 32 of Set 9 | naryan-mar
# Processing Record 33 of Set 9 | abu kamal
# Processing Record 34 of Set 9 | cherskiy
# Processing Record 35 of Set 9 | zheleznodorozhnyy
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | nizhniy tsasuchey
# Processing Record 38 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 39 of Set 9 | la ligua
# Processing Record 40 of Set 9 | shenjiamen
# Processing Record 41 of Set 9 | ugoofaaru
# Processing Record 42 of Set 9 | copiapo
# Processing Record 43 of Set 9 | saint-pierre
# Processing Record 44 of Set 9 | bazpur
# Processing Record 45 of Set 9 | quatre cocos
# Processing Record 46 of Set 9 | charters towers
# Processing Record 47 of Set 9 | roebourne
# Processing Record 48 of Set 9 | cooma
# Processing Record 49 of Set 9 | mangai
# Processing Record 50 of Set 9 | sri aman
# Processing Record 1 of Set 10 | luganville
# Processing Record 2 of Set 10 | paso de los toros
# Processing Record 3 of Set 10 | labuhan
# Processing Record 4 of Set 10 | tiksi
# Processing Record 5 of Set 10 | piet retief
# Processing Record 6 of Set 10 | wahpeton
# Processing Record 7 of Set 10 | namatanai
# Processing Record 8 of Set 10 | maceio
# Processing Record 9 of Set 10 | walvis bay
# Processing Record 10 of Set 10 | rogun
# City not found. Skipping...
# Processing Record 11 of Set 10 | tiptur
# Processing Record 12 of Set 10 | catuday
# Processing Record 13 of Set 10 | kirkcudbright
# Processing Record 14 of Set 10 | klaksvik
# Processing Record 15 of Set 10 | penjamillo
# City not found. Skipping...
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 10 | raga
# Processing Record 19 of Set 10 | port hedland
# Processing Record 20 of Set 10 | bhan
# Processing Record 21 of Set 10 | bronnoysund
# Processing Record 22 of Set 10 | caravelas
# Processing Record 23 of Set 10 | douglas
# Processing Record 24 of Set 10 | victor harbor
# Processing Record 25 of Set 10 | svetlogorsk
# Processing Record 26 of Set 10 | sungurlu
# Processing Record 27 of Set 10 | grand gaube
# Processing Record 28 of Set 10 | san lawrenz
# Processing Record 29 of Set 10 | eyl
# Processing Record 30 of Set 10 | carroll
# Processing Record 31 of Set 10 | muroto
# Processing Record 32 of Set 10 | rabo de peixe
# Processing Record 33 of Set 10 | abha
# Processing Record 34 of Set 10 | pavlovka
# Processing Record 35 of Set 10 | elizabeth city
# Processing Record 36 of Set 10 | nioro
# Processing Record 37 of Set 10 | constitucion
# Processing Record 38 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 10 | tianpeng
# Processing Record 40 of Set 10 | sfantu gheorghe
# Processing Record 41 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 10 | yamada
# Processing Record 43 of Set 10 | sukhodol
# Processing Record 44 of Set 10 | teeli
# Processing Record 45 of Set 10 | bengkulu
# Processing Record 46 of Set 10 | ewo
# Processing Record 47 of Set 10 | sorrento
# Processing Record 48 of Set 10 | sangar
# Processing Record 49 of Set 10 | calabozo
# Processing Record 50 of Set 10 | subtanjalla
# Processing Record 1 of Set 11 | jaguaruana
# Processing Record 2 of Set 11 | atar
# Processing Record 3 of Set 11 | teguldet
# Processing Record 4 of Set 11 | hadsund
# Processing Record 5 of Set 11 | laurel
# Processing Record 6 of Set 11 | rehoboth
# Processing Record 7 of Set 11 | kununurra
# Processing Record 8 of Set 11 | pisco
# Processing Record 9 of Set 11 | tura
# Processing Record 10 of Set 11 | necochea
# Processing Record 11 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 12 of Set 11 | biak
# Processing Record 13 of Set 11 | beisfjord
# Processing Record 14 of Set 11 | tucuman
# Processing Record 15 of Set 11 | fairbanks
# Processing Record 16 of Set 11 | pangoa
# Processing Record 17 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 11 | punta alta
# Processing Record 20 of Set 11 | amahai
# Processing Record 21 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 22 of Set 11 | sao jose da coroa grande
# Processing Record 23 of Set 11 | troy
# Processing Record 24 of Set 11 | fuyu
# Processing Record 25 of Set 11 | makakilo city
# Processing Record 26 of Set 11 | fort wellington
# Processing Record 27 of Set 11 | chau doc
# Processing Record 28 of Set 11 | pascagoula
# Processing Record 29 of Set 11 | saint-augustin
# Processing Record 30 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 32 of Set 11 | chaguani
# Processing Record 33 of Set 11 | macon
# Processing Record 34 of Set 11 | muscle shoals
# Processing Record 35 of Set 11 | otane
# Processing Record 36 of Set 11 | villa bruzual
# Processing Record 37 of Set 11 | deep river
# Processing Record 38 of Set 11 | kieta
# Processing Record 39 of Set 11 | bosaso
# Processing Record 40 of Set 11 | yabrud
# Processing Record 41 of Set 11 | mehamn
# Processing Record 42 of Set 11 | ganzhou
# Processing Record 43 of Set 11 | lebu
# Processing Record 44 of Set 11 | kalevala
# Processing Record 45 of Set 11 | saint-ambroise
# Processing Record 46 of Set 11 | aswan
# Processing Record 47 of Set 11 | port shepstone
# Processing Record 48 of Set 11 | soyo
# Processing Record 49 of Set 11 | kyabe
# Processing Record 50 of Set 11 | bure
# Processing Record 1 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 12 | aban
# Processing Record 3 of Set 12 | lexington
# Processing Record 4 of Set 12 | skaudvile
# Processing Record 5 of Set 12 | lahaina
# Processing Record 6 of Set 12 | nishihara
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | ajaccio
# Processing Record 9 of Set 12 | roald
# Processing Record 10 of Set 12 | paracuru
# Processing Record 11 of Set 12 | moba
# Processing Record 12 of Set 12 | vaitape
# Processing Record 13 of Set 12 | poltavka
# Processing Record 14 of Set 12 | koubia
# Processing Record 15 of Set 12 | ozernovskiy
# Processing Record 16 of Set 12 | pelym
# Processing Record 17 of Set 12 | rio gallegos
# Processing Record 18 of Set 12 | bud
# Processing Record 19 of Set 12 | broken hill
# Processing Record 20 of Set 12 | peachland
# Processing Record 21 of Set 12 | mogzon
# Processing Record 22 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 12 | kandrian
# Processing Record 24 of Set 12 | bartlesville
# Processing Record 25 of Set 12 | barcelos
# Processing Record 26 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 12 | troitsko-pechorsk
# Processing Record 28 of Set 12 | aksu
# Processing Record 29 of Set 12 | haapiti
# Processing Record 30 of Set 12 | hovd
# Processing Record 31 of Set 12 | ngunguru
# Processing Record 32 of Set 12 | gat
# Processing Record 33 of Set 12 | hualmay
# Processing Record 34 of Set 12 | sept-iles
# Processing Record 35 of Set 12 | chapais
# Processing Record 36 of Set 12 | mackenzie
# Processing Record 37 of Set 12 | arman
# Processing Record 38 of Set 12 | dabrowa tarnowska
# Processing Record 39 of Set 12 | kozyatyn
# Processing Record 40 of Set 12 | anadyr
# Processing Record 41 of Set 12 | cachira
# Processing Record 42 of Set 12 | limbang
# Processing Record 43 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 12 | basco
# Processing Record 45 of Set 12 | navirai
# Processing Record 46 of Set 12 | port moresby
# Processing Record 47 of Set 12 | onokhoy
# Processing Record 48 of Set 12 | geraldton
# Processing Record 49 of Set 12 | qasigiannguit
# Processing Record 50 of Set 12 | kailua
# Processing Record 1 of Set 13 | gillette
# Processing Record 2 of Set 13 | lalibela
# Processing Record 3 of Set 13 | olafsvik
# Processing Record 4 of Set 13 | vardo
# Processing Record 5 of Set 13 | makinsk
# Processing Record 6 of Set 13 | vao
# Processing Record 7 of Set 13 | toora-khem
# Processing Record 8 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 13 | aquiraz
# Processing Record 10 of Set 13 | praia
# Processing Record 11 of Set 13 | sosnovo-ozerskoye
# Processing Record 12 of Set 13 | aykhal
# Processing Record 13 of Set 13 | lukoyanov
# Processing Record 14 of Set 13 | sandwick
# Processing Record 15 of Set 13 | alyangula
# Processing Record 16 of Set 13 | kedougou
# Processing Record 17 of Set 13 | gondanglegi
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 565

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  \
# 0             toul  48.6667    5.9167     68.29           clear sky
# 1            nalut  30.3333   10.8500     85.78           clear sky
# 2  bambous virieux -20.3428   57.7575     68.25       broken clouds
# 3           jacmel  18.2342  -72.5347     80.44    scattered clouds
# 4        mahebourg -20.4081   57.7000     69.26       broken clouds
# 5       marakkanam  12.2000   79.9500     81.27     overcast clouds
# 6          rikitea -23.1203 -134.9692     74.10     overcast clouds
# 7       bredasdorp -34.5322   20.0403     49.78           clear sky
# 8           albany  42.6001  -73.9662     83.17     overcast clouds
# 9           lompoc  34.6391 -120.4579     87.01           clear sky
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0              0        52           0        6.91      FR
# 1            0.0              0        18           0       11.86      LY
# 2            0.0              0        83          75        8.05      MU
# 3            0.0              0        74          36        6.31      HT
# 4            0.0              0        83          75        8.05      MU
# 5            0.0              0        81         100        4.70      IN
# 6            0.0              0        69          97       14.99      PF
# 7            0.0              0        90           0        4.63      ZA
# 8            0.0              0        51          99        2.93      US
# 9            0.0              0        72           0       14.00      US

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description', 
                    'Rain (inches)', 'Snow (inches)']

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             toul      FR  48.6667    5.9167     68.29        52           0
# 1            nalut      LY  30.3333   10.8500     85.78        18           0
# 2  bambous virieux      MU -20.3428   57.7575     68.25        83          75
# 3           jacmel      HT  18.2342  -72.5347     80.44        74          36
# 4        mahebourg      MU -20.4081   57.7000     69.26        83          75
# 5       marakkanam      IN  12.2000   79.9500     81.27        81         100
# 6          rikitea      PF -23.1203 -134.9692     74.10        69          97
# 7       bredasdorp      ZA -34.5322   20.0403     49.78        90           0
# 8           albany      US  42.6001  -73.9662     83.17        51          99
# 9           lompoc      US  34.6391 -120.4579     87.01        72           0
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        6.91           clear sky            0.0              0
# 1       11.86           clear sky            0.0              0
# 2        8.05       broken clouds            0.0              0
# 3        6.31    scattered clouds            0.0              0
# 4        8.05       broken clouds            0.0              0
# 5        4.70     overcast clouds            0.0              0
# 6       14.99     overcast clouds            0.0              0
# 7        4.63           clear sky            0.0              0
# 8        2.93     overcast clouds            0.0              0
# 9       14.00           clear sky            0.0              0

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)'] > 0]
raining_cities.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 21         ughelli      NG   5.4899    6.0074     73.81        95         100
# 65   mar del plata      AR -38.0023  -57.5575     54.09        60         100
# 77             qom      IR  34.6401   50.8764     90.66        29          37
# 90           bluff      NZ -46.6000  168.3333     47.80        87         100
# 118        ahipara      NZ -35.1667  173.1667     58.71        90          31
#
#      Wind Speed Current Description  Rain (inches)  Snow (inches)
# 21         5.23       moderate rain           1.07              0
# 65         6.91       moderate rain           1.54              0
# 77         8.30          light rain           0.11              0
# 90        12.03          light rain           0.15              0
# 118       17.63          light rain           0.11              0

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)'] > 0]
snowing_cities
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
